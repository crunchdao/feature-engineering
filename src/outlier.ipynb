# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from class_ import  Data
# Out:
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
f_matrix = pd.read_parquet("../data/f_matrix.parquet")
b_matrix = pd.read_parquet("../data/f_matrix.parquet")

# %%
f_matrix
# Out:
#             date  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0     2016-02-17     -0.376     -0.699     -0.507     0.4536    -0.0752
# 1     2016-02-17     -1.121      1.073      0.234     0.4986     0.0022
# 2     2016-02-17     -0.384     -0.097      0.100     0.9720    -0.1626
# 3     2016-02-17     -0.343      0.542      0.143     0.1034    -0.6422
# 4     2016-02-17     -0.562      0.137     -0.213    -0.1744    -0.5152
# ...          ...        ...        ...        ...        ...        ...
# 50029 2017-01-25     -1.007      0.638      0.940    -0.0046     0.3900
# 50030 2017-01-25     -1.314      0.000      1.711     2.7674     2.8544
# 50031 2017-01-25     -1.124      0.950      1.456     0.4290     0.0460
# 50032 2017-01-25     -0.432      0.205      1.976    -0.1886     1.1320
# 50033 2017-01-25      0.107      0.294      0.777    -0.3548     1.8886
#
#        feature_5  feature_6
# 0        -0.2548  -0.191619
# 1         0.6890  -0.596857
# ...

# %%
d = Data(f_matrix, b_matrix)

# %%
cross_sectional_moments = d.cross_sectional_moments()

# %%
cross_sectional_moments
# Out:
#     moon  feature_0_std  feature_0_skew  feature_0_kurt  feature_1_std  \
# 0      0       0.807020        0.022835        1.469744       0.586943
# 1      1       0.792753       -0.160802        1.425351       0.587589
# 2      2       0.859671        0.049192        1.959333       0.595241
# 3      3       0.855659        0.063761        1.614890       0.598859
# 4      4       0.840004        0.117626        1.635171       0.593921
# 5      5       0.812158        0.082136        1.436377       0.590866
# 6      6       0.838087       -0.090614        1.607290       0.588803
# 7      7       0.810454        0.231288        1.665578       0.578968
# 8      8       0.758312        0.122030        1.693137       0.574345
# 9      9       0.761857       -0.069659        1.687359       0.568842
# 10    10       0.792212       -0.060173        1.845085       0.569272
# 11    11       0.804342       -0.107257        2.085566       0.568425
# ...

# %%
import matplotlib.pyplot as plt

# %%
for i in cross_sectional_moments.columns[1:]:
    df = cross_sectional_moments.loc[:, i].plot()
    plt.title(f'{i}')
    plt.show()
