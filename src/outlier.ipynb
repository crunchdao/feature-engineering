# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from class_ import  Data

# %%
f_matrix = pd.read_parquet("../data/f_matrix.parquet")
b_matrix = pd.read_parquet("../data/f_matrix.parquet")

# %%
d = Data(f_matrix, b_matrix)

# %%
moon_wise_mom = d.moon_wise_moment()

# %%
moon_wise_mom
# Out:
#      feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    -0.013344   0.326113  -0.040328   0.229160   0.162043   0.129927
# 1     0.807020   0.586943   0.846769   0.798813   0.819252   0.543602
# 2     0.022835  -0.476180   0.231390   1.591104   1.041831   0.348714
# 3     1.469744   1.780109   0.289771   2.875897   1.294352   6.773333
# 4     0.002520   0.328745  -0.037208   0.225069   0.157792   0.142060
# ..         ...        ...        ...        ...        ...        ...
# 195   1.402419   1.353779   0.197098   2.192726   0.899416   6.750437
# 196   0.002074   0.307009   0.371990   0.172732   0.121934  -0.115667
# 197   0.796934   0.584085   0.959062   0.848538   0.879957   0.598253
# 198  -0.004641  -0.325854  -0.069561   1.330443   0.717066   0.375854
# 199   2.237935   1.365943   0.200248   2.166603   0.876836   6.792494
#
#      feature_6 moon    moment
# 0    -0.007329    0      mean
# 1     0.804617    0       std
# 2    -0.282081    0  skewness
# 3     0.751315    0  kurtosis
# 4    -0.006715    1      mean
# ..         ...  ...       ...
# 195   0.505573   48  kurtosis
# 196   0.006819   49      mean
# 197   0.831604   49       std
# 198  -0.136764   49  skewness
# 199   0.518780   49  kurtosis
#
# [200 rows x 9 columns]
